# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import torch
#       2 print(torch.cuda.is_available())
# ----> 3 print(torch.cuda.get_device_name(0))
#
# File ~\anaconda3\Lib\site-packages\torch\cuda\__init__.py:582, in get_device_name(device)
#     570 def get_device_name(device: "Device" = None) -> str:
#     571     r"""Get the name of a device.
#     572
#     573     Args:
#    (...)
#     580         str: the name of the device
#     581     """
# --> 582     return get_device_properties(device).name
#
# File ~\anaconda3\Lib\site-packages\torch\cuda\__init__.py:614, in get_device_properties(device)
#     602 def get_device_properties(device: "Device" = None) -> _CudaDeviceProperties:
#     603     r"""Get the properties of a device.
#     604
#     605     Args:
#    (...)
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
model.train(data="dataset/data.yaml", epochs=50, device=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.train(data="dataset/data.yaml", epochs=50, device=0)
#
# NameError: name 'model' is not defined

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")   # or your model .pt file

# %%
model.train(data="dataset/data.yaml", epochs=50, device=0)
# Out:
# Ultralytics 8.3.229  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"runs/detect/train2/weights/best.pt")
results = model("dataset/test/images/0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg", show=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from ultralytics import YOLO
#       3 model = YOLO(r"runs/detect/train2/weights/best.pt")
# ----> 4 results = model("Poaching_Detection/dataset/test/images/0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg", show=True)
#
# File ~\yolo_gpu_env\lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     154 def __call__(
#     155     self,
#     156     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     157     stream: bool = False,
#     158     **kwargs: Any,
#     159 ) -> list:
#     160     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"runs/detect/train2/weights/best.pt")
results = model(r"/mnt/data/0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg", show=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 from ultralytics import YOLO
#       3 model = YOLO(r"runs/detect/train2/weights/best.pt")
# ----> 4 results = model(r"/mnt/data/0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg", show=True)
#
# File ~\yolo_gpu_env\lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     154 def __call__(
#     155     self,
#     156     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     157     stream: bool = False,
#     158     **kwargs: Any,
#     159 ) -> list:
#     160     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#     162     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"runs/detect/train2/weights/best.pt")
results = model("dataset/test/images/0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg", show=True)
# Out:
# image 1/1 C:\Users\Vivin Vaibhav L K\Poaching_Detection\dataset\test\images\0a66dde6c8_jpg.rf.5b87ab39edc2abb7cfbb5f10513b5bd4.jpg: 640x640 1 Hyena, 111.7ms
# Speed: 8.7ms preprocess, 111.7ms inference, 20.6ms postprocess per image at shape (1, 3, 640, 640)
